# %% [markdown]
# # RL Env deebugger

# %%
from RL_envdirectcontrol import CarENV
import numpy as np
import time
import random
from stable_baselines3 import PPO
from stable_baselines3 import DQN
import os 
import stable_baselines3
print(stable_baselines3.__version__)
# Out:
# 2.0.0

# %%
start_end_dic = {147:[146]
                 
                 }
# start_end_dic = {132:[6,7,8,9,11,12,15,16,20]}

actor = CarENV(show_local_view=True, no_render_mode=False, Debugger= False , start_end_dic= start_end_dic, action_space_type='Discrete') 
# from stable_baselines3.common.env_checker import check_env
# check_env(actor, warn=True, skip_render_check=True)

# %%
from stable_baselines3.common.callbacks import StopTrainingOnMaxEpisodes


callback_max_episodes = StopTrainingOnMaxEpisodes(max_episodes= 30000, verbose=1)

# %%
Note = 'vegetation + globally guided + start_point_fixed+ limited end poin endpoints[5:20]'     
models_dir = f"models/onlyroad" #DQN_overfitting_2"
logdir = f"trainingdir/onlyroad"
Attempt =  'triall'

if not os.path.exists(models_dir):
    os.makedirs(models_dir)

if not os.path.exists(logdir):
    os.makedirs(logdir)
params = {'learning_ratee': 0.0001}

policy = 'ActorCriticCnnPolicy'
model = DQN('CnnPolicy',actor, verbose=1, buffer_size=10000, tensorboard_log=logdir)
actor.render_mode = None
model.learn(total_timesteps=1000000 , callback=callback_max_episodes,log_interval = 4)
reset_num_timesteps=False
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# []
# []
# The environmnet has been reset. The total reward was 0. And steps were 0 and the episode is 0 and the total_steps are 0
# .Logging to trainingdir/onlyroad\DQN_1
# the action is [steering, throttle] = 3
# First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 1
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 2
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 3
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 390 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 1
#
# Crossed line 'SolidSolid'
#
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# Done condition: off road
# The reward is -1010 and done isTrue, and steps since g = 1
# [Actor(id=24, type=vehicle.tesla.model3)]
# [3, 0, 2, 1, 2, 3, 0, 1, 1]
# The environmnet has been reset. The total reward was -390. And steps were 9 and the episode is 1 and the total_steps are 9
# the action is [steering, throttle] = 3
# First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 1
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 2
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 3
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 4
#
# Crossed line 'Broken'
#
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 490 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
#
# Crossed line 'Broken'
#
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# Done condition: off road
# The reward is -1010 and done isTrue, and steps since g = 0
#
# Crossed line 'Broken'
#
# [Actor(id=28, type=vehicle.tesla.model3)]
#
# Crossed line 'SolidSolid'
#
# [3, 1, 2, 1, 1, 2, 0, 3, 0, 3, 0]
# The environmnet has been reset. The total reward was -110. And steps were 11 and the episode is 2 and the total_steps are 20
# the action is [steering, throttle] = 3
# First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 1
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 2
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 3
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 390 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
#
# Crossed line 'Broken'
#
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
#
# Crossed line 'Broken'
#
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 2
# First time visit
# The reward is 90 and done isFalse, and steps since g = 0
#
# Crossed line 'Broken'
#
# the action is [steering, throttle] = 3
# The reward is -100 and done isFalse, and steps since g = 1
#
# Crossed line 'Solid'
#
#
# Crossed line 'Broken'
#
# the action is [steering, throttle] = 3
# Done condition: off road
# The reward is -1010 and done isTrue, and steps since g = 1
# [Actor(id=32, type=vehicle.tesla.model3)]
# [3, 3, 2, 0, 3, 2, 1, 3, 1, 1, 3, 3, 1, 2, 3, 3]
# The environmnet has been reset. The total reward was 150. And steps were 16 and the episode is 3 and the total_steps are 36
# the action is [steering, throttle] = 3
# First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 1
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 2
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 3
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 390 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 1
#
# Crossed line 'SolidSolid'
#
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# Done condition: off road
# The reward is -1010 and done isTrue, and steps since g = 1
# [Actor(id=36, type=vehicle.tesla.model3)]
# [3, 0, 0, 2, 2, 3, 0, 3, 2]
# The environmnet has been reset. The total reward was -390. And steps were 9 and the episode is 4 and the total_steps are 45
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.2     |
# |    ep_rew_mean      | -185     |
# |    exploration_rate | 1        |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 18       |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 45       |
# ----------------------------------
# the action is [steering, throttle] = 1
# First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 1
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 2
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 3
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 390 and done isFalse, and steps since g = 0
#
# Crossed line 'Broken'
#
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -100 and done isFalse, and steps since g = 1
#
# Crossed line 'Broken'
#
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -100 and done isFalse, and steps since g = 2
# the action is [steering, throttle] = 1
# The reward is -100 and done isFalse, and steps since g = 3
#
# Crossed line 'Solid'
#
#
# Crossed line 'Solid'
#
#
# Crossed line 'Broken'
#
# the action is [steering, throttle] = 3
# Done condition: off road
# The reward is -1010 and done isTrue, and steps since g = 3
#
# Crossed line 'Broken'
#
# [Actor(id=40, type=vehicle.tesla.model3)]
# [1, 3, 0, 3, 3, 3, 2, 2, 2, 1, 3]
# The environmnet has been reset. The total reward was -680. And steps were 11 and the episode is 5 and the total_steps are 56
# the action is [steering, throttle] = 2
# First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 1
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 2
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 3
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 390 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
#
# Crossed line 'SolidSolid'
#
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# Done condition: off road
# The reward is -1010 and done isTrue, and steps since g = 0
# [Actor(id=44, type=vehicle.tesla.model3)]
#
# Crossed line 'SolidSolid'
#
# [2, 2, 2, 0, 0, 2, 0, 2, 1, 3, 2]
# The environmnet has been reset. The total reward was -110. And steps were 11 and the episode is 6 and the total_steps are 67
# the action is [steering, throttle] = 0
# First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 1
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 2
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 3
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 390 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
#
# Crossed line 'Broken'
#
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -100 and done isFalse, and steps since g = 1
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 190 and done isFalse, and steps since g = 0
#
# Crossed line 'Broken'
#
# the action is [steering, throttle] = 1
# The reward is -100 and done isFalse, and steps since g = 1
#
# Crossed line 'Solid'
#
#
# Crossed line 'Broken' and 'Solid'
#
#
# Crossed line 'Broken' and 'Solid'
#
# the action is [steering, throttle] = 2
# Done condition: off road
# The reward is -1010 and done isTrue, and steps since g = 1
#
# Crossed line 'Broken'
#
# [Actor(id=48, type=vehicle.tesla.model3)]
# [0, 1, 1, 0, 0, 2, 3, 3, 2, 2, 1, 2]
# The environmnet has been reset. The total reward was -300. And steps were 12 and the episode is 7 and the total_steps are 79
# the action is [steering, throttle] = 0
# First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 1
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 2
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 3
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 4
#
# Crossed line 'SolidSolid'
#
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# Done condition: off road
# The reward is -1010 and done isTrue, and steps since g = 4
# [Actor(id=52, type=vehicle.tesla.model3)]
# [0, 1, 2, 0, 3, 3, 3, 2]
# The environmnet has been reset. The total reward was -780. And steps were 8 and the episode is 8 and the total_steps are 87
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | -326     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 18       |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 87       |
# ----------------------------------
# the action is [steering, throttle] = 2
# First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 1
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 2
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 3
#
# Crossed line 'SolidSolid'
#
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Done condition: off road
# The reward is -1010 and done isTrue, and steps since g = 3
# [Actor(id=56, type=vehicle.tesla.model3)]
# [2, 1, 1, 0, 0, 0, 3]
# The environmnet has been reset. The total reward was -770. And steps were 7 and the episode is 9 and the total_steps are 94
# the action is [steering, throttle] = 1
# First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 1
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 2
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 3
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 4
#
# Crossed line 'SolidSolid'
#
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# Done condition: off road
# The reward is -1010 and done isTrue, and steps since g = 4
# [Actor(id=60, type=vehicle.tesla.model3)]
# [1, 0, 3, 1, 0, 3, 3, 3]
# The environmnet has been reset. The total reward was -780. And steps were 8 and the episode is 10 and the total_steps are 102
# the action is [steering, throttle] = 1
# First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 1
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 2
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 3
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 390 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
#
# Crossed line 'SolidSolid'
#
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# Done condition: off road
# The reward is -1010 and done isTrue, and steps since g = 0
# [Actor(id=64, type=vehicle.tesla.model3)]
# [1, 0, 2, 1, 2, 3, 1, 3, 3, 1, 0]
# The environmnet has been reset. The total reward was -110. And steps were 11 and the episode is 11 and the total_steps are 113
# the action is [steering, throttle] = 3
# First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 1
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 2
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 3
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 4
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 490 and done isFalse, and steps since g = 0
#
# Crossed line 'Broken'
#
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
#
# Crossed line 'Broken'
#
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -100 and done isFalse, and steps since g = 1
#
# Crossed line 'Solid'
#
# the action is [steering, throttle] = 0
# Done condition: off road
# The reward is -1010 and done isTrue, and steps since g = 1
#
# Crossed line 'Solid'
#
#
# Crossed line 'Broken'
#
# [Actor(id=68, type=vehicle.tesla.model3)]
#
# Crossed line 'Broken'
#
# [3, 1, 2, 0, 2, 1, 2, 0, 2, 2, 2, 0]
# The environmnet has been reset. The total reward was -210. And steps were 12 and the episode is 12 and the total_steps are 125
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | -373     |
# |    exploration_rate | 0.999    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 19       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 125      |
# ----------------------------------
# the action is [steering, throttle] = 0
# First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 1
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 2
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 3
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 390 and done isFalse, and steps since g = 0
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# Done condition: off road
# The reward is -1010 and done isTrue, and steps since g = 0
# [Actor(id=72, type=vehicle.tesla.model3)]
# [0, 2, 0, 0, 1, 3, 2, 3]
# The environmnet has been reset. The total reward was -380. And steps were 8 and the episode is 13 and the total_steps are 133
# the action is [steering, throttle] = 3
# First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 1
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 2
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 3
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 390 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
#
# Crossed line 'Solid'
#
# the action is [steering, throttle] = 3
# Done condition: off road
# The reward is -1010 and done isTrue, and steps since g = 0
#
# Crossed line 'Broken'
#
#
# Crossed line 'Solid'
#
# [Actor(id=76, type=vehicle.tesla.model3)]
#
# Crossed line 'Broken'
#
# [3, 0, 1, 1, 3, 1, 3, 1, 2, 2, 1, 3]
# The environmnet has been reset. The total reward was -20. And steps were 12 and the episode is 14 and the total_steps are 145
# the action is [steering, throttle] = 0
# First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 1
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 2
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 3
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 4
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 490 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
#
# Crossed line 'SolidSolid'
#
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# Done condition: off road
# The reward is -1010 and done isTrue, and steps since g = 0
# [Actor(id=80, type=vehicle.tesla.model3)]
# [0, 0, 0, 2, 1, 3, 2, 1, 3, 3]
# The environmnet has been reset. The total reward was -200. And steps were 10 and the episode is 15 and the total_steps are 155
# the action is [steering, throttle] = 3
# First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 1
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 2
# the action is [steering, throttle] = 1
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 3
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 4
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 490 and done isFalse, and steps since g = 0
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# Done condition: off road
# The reward is -1010 and done isTrue, and steps since g = 0
# [Actor(id=84, type=vehicle.tesla.model3)]
# [3, 2, 3, 3, 1, 1, 3, 2, 0]
# The environmnet has been reset. The total reward was -290. And steps were 9 and the episode is 16 and the total_steps are 164
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | -336     |
# |    exploration_rate | 0.998    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 19       |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 164      |
# ----------------------------------
# the action is [steering, throttle] = 3
# First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 2
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||First time visit
# The reward is 90 and done isFalse, and steps since g = 0
# the action is [steering, throttle] = 3
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 1
# the action is [steering, throttle] = 0
# Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||Sorry you have visited this waypoint before ||The reward is -10 and done isFalse, and steps since g = 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15496\2770411915.py in <module>
#      14 model = DQN('CnnPolicy',actor, verbose=1, buffer_size=10000, tensorboard_log=logdir)
#      15 actor.render_mode = None
# ---> 16 model.learn(total_timesteps=1000000 , callback=callback_max_episodes,log_interval = 4)
#      17 reset_num_timesteps=False
#      18
#
# c:\Users\netbot\anaconda3\envs\CARLA\lib\site-packages\stable_baselines3\dqn\dqn.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     271             tb_log_name=tb_log_name,
#     272             reset_num_timesteps=reset_num_timesteps,
# --> 273             progress_bar=progress_bar,
#     274         )
#     275
#
# c:\Users\netbot\anaconda3\envs\CARLA\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     317                 learning_starts=self.learning_starts,
#     318                 replay_buffer=self.replay_buffer,
# --> 319                 log_interval=log_interval,
#     320             )
#     321
#
# c:\Users\netbot\anaconda3\envs\CARLA\lib\site-packages\stable_baselines3\common\off_policy_algorithm.py in collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     542
#     543             # Rescale and perform action
# --> 544             new_obs, rewards, dones, infos = env.step(actions)
#     545
#     546             self.num_timesteps += env.num_envs
#
# c:\Users\netbot\anaconda3\envs\CARLA\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py in step(self, actions)
#     195         """
#     196         self.step_async(actions)
# --> 197         return self.step_wait()
#     198
#     199     def get_images(self) -> Sequence[Optional[np.ndarray]]:
#
# c:\Users\netbot\anaconda3\envs\CARLA\lib\site-packages\stable_baselines3\common\vec_env\vec_transpose.py in step_wait(self)
#      93
#      94     def step_wait(self) -> VecEnvStepReturn:
# ---> 95         observations, rewards, dones, infos = self.venv.step_wait()
#      96
#      97         # Transpose the terminal observations
#
# c:\Users\netbot\anaconda3\envs\CARLA\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in step_wait(self)
#      69                 self.buf_infos[env_idx]["terminal_observation"] = obs
#      70                 obs, self.reset_infos[env_idx] = self.envs[env_idx].reset()
# ---> 71             self._save_obs(env_idx, obs)
#      72         return (self._obs_from_buf(), np.copy(self.buf_rews), np.copy(self.buf_dones), deepcopy(self.buf_infos))
#      73
#
# c:\Users\netbot\anaconda3\envs\CARLA\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py in _save_obs(self, env_idx, obs)
#     104         for key in self.keys:
#     105             if key is None:
# --> 106                 self.buf_obs[key][env_idx] = obs
#     107             else:
#     108                 self.buf_obs[key][env_idx] = obs[key]  # type: ignore[call-overload]
#
# KeyboardInterrupt:
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken' and 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'SolidSolid'

# %%
# print(f"The self.camera_observation is {actor.camera_observation}" )

if actor.actor_lst:
    actor.destroy_all_actors()
# Out:
# Crossed line 'SolidSolid'
#
#
# Crossed line 'Broken'
#
#
# Crossed line 'Broken'
#
# [Actor(id=88, type=vehicle.tesla.model3)]

# %%
model.save(f'{models_dir}/model_{Attempt}')

# %%
del model
try:
    print(model)
except:
    print("This can not be deleted")
# Out:
# This can not be deleted

# %%
actor.seconds_per_episode
model = DQN.load(f'{models_dir}/model_{Attempt}.zip')

# %%
# obs,info = actor.reset()

# for i in range(10):
#     actions = []
#     while True:s
#         action, _states= model.predict(observation = obs, deterministic=True)
#         actions.append(action)
#         obs, reward,_, terminated, info = actor.step(action)
    
#         if terminated:
#             print(actions)
#             obs, info = actor.reset()
#             break

# print(f"The self.camera_observation is {actor.camera_observation}" )

# if actor.actor_lst:
#     actor.destroy_all_actors()
