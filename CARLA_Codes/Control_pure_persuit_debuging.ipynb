# %% [markdown]
# # Control testing using pure pursuit controller debugging

# %%
import sys
import math 
import random 
import time 
import numpy as np
import cv2
import matplotlib.pyplot as plt
import carla

#  Trying to import the Global and Local 
sys.path.append(("C:/CARLA/WindowsNoEditor/PythonAPI/carla"))
from agents.navigation.global_route_planner import GlobalRoutePlanner


''' Connecting to Carla and fetching blue-print of the map'''

# Connect the client and set up bp library and spawn point
client = carla.Client('localhost', 2000)
client.set_timeout(20.0)
world = client.get_world()
bp_lib = world.get_blueprint_library() 
spawn_points = world.get_map().get_spawn_points() 


settings = world.get_settings()
settings.no_rendering_mode = False
world.apply_settings(settings)
# Out:
# 5661

# %%
# start_location=carla.Transform(carla.Location(x=67.659744, y=69.822777, z=0.600000), carla.Rotation(pitch=0.000000, yaw=0.073273, roll=0.000000))
# end_location = carla.Transform(carla.Location(x=-67.254570, y=27.963758, z=0.600000), carla.Rotation(pitch=0.000000, yaw=0.159198, roll=0.000000))
start_location = random.choice(spawn_points)
print(start_location)
end_location = random.choice(spawn_points)
print(end_location)
start_point = start_location.location
end_point = end_location.location
# Out:
# Transform(Location(x=99.078560, y=42.141800, z=0.600000), Rotation(pitch=0.000000, yaw=90.390709, roll=0.000000))
# Transform(Location(x=79.055290, y=69.822777, z=0.600000), Rotation(pitch=0.000000, yaw=0.073273, roll=0.000000))

# %%
Kdd = 0.4
FPS = 30
dt  = 1./FPS
L = 2.875 #### Will need to check how to get 
sampling_resolution = 3

# %%
def get_target_wp_index(veh_location, waypoint_list):
    ''' 
    Try to implement next target index using this method
    http://paulbourke.net/geometry/pointlineplane/

    return:
    idx = index of the waypoint
    (tx,ty) = the target coordinate
    info (bool) =  true if last waypoint is clicked 

    Implementation given here
    '''
    print(f'the last location in the list {waypoint_list[-1]}')
    info = False
    exception = False
    dxl, dyl = [], []
    for i in range(len(waypoint_list)):
        dx = abs(veh_location.x - waypoint_list[i][0])
        dxl.append(dx) #list of dx1
        dy = abs(veh_location.y - waypoint_list[i][1])
        dyl.append(dy)

    dist = np.hypot(dxl, dyl)
    try:
        idx = np.argmin(dist) + 4 
    except: idx = 4
    # take closest waypoint, else last wp

    if idx < len(waypoint_list):
        print(f'This line is printed')
        tx = waypoint_list[idx][0]
        ty = waypoint_list[idx][1]

    else:
        print(f'the exception is printed')
        tx = waypoint_list[-1][0]
        ty = waypoint_list[-1][1]
        exception = True
    print(f'The current waypoint is {(tx, ty)}, and the indexis = {idx}')

    if (tx, ty) == waypoint_list[-1] :
        print("This is the new condition tyhat was printed")
        info = True
    return idx, (tx, ty), info

# %%
def process_img(image):
    i = np.array(image.raw_data)
    i2 = i.reshape((IM_HEIGHT, IM_WIDTH, 4))
    i3 = i2[:, :, :3]
    # cv2.imshow("", i3)
    # cv2.waitKey(1)
    return i3/255.0

'''SPAWNING'''
actor_lst = list()


'''spawning vehicle'''


v_bp = bp_lib.filter('vehicle.tesla.model3')[0]

vehicle = world.try_spawn_actor(v_bp,start_location)
actor_lst.append(vehicle)


# '''Adding Static Vehicle'''
# traffic_bp = bp_lib.filter("vehicle.*")

# policy = [0, 1]
# for point in spawn_points:
#     if random.choice(policy):
#         if not (point == start_location or point == end_location):
#             traffic_vehicle = random.choice(traffic_bp)
#             actor_lst.append(world.try_spawn_actor(traffic_vehicle, point))
#             # print(traffic_vehicle, point, sep='\n')


'''Adding a sensor '''
IM_WIDTH = 640
IM_HEIGHT = 480
camera_bp = bp_lib.find("sensor.camera.rgb")
camera_bp.set_attribute('image_size_x', f'{IM_WIDTH}')
camera_bp.set_attribute('image_size_y', f'{IM_HEIGHT}')
camera_bp.set_attribute('fov', '110')


 # Adjust sensor relative to vehicle
camera_spawn = carla.Transform(carla.Location(x=-4, z=2.5))

# spawn the sensor and attach to vehicle.
sensor = world.try_spawn_actor(camera_bp, camera_spawn, attach_to=vehicle)

# add sensor to list of actors
actor_lst.append(sensor)

# do something with this sensor
sensor.listen(lambda data: process_img(data))

# %%
'''Tracing a route between the two specified point '''

 
grp = GlobalRoutePlanner(world.get_map(), sampling_resolution)
route =  grp.trace_route(start_point, end_point)

''' This is just to visualize the route'''
for waypoint in route:
    world.debug.draw_string(waypoint[0].transform.location, '^', draw_shadow=False,
        color=carla.Color(r=0, g=0, b=255), life_time=60.0,
        persistent_lines=True)
    
print("Done")

waypoint_lst = []
i = 0
for waypoint, _ in route:
    i+=1
    loc = waypoint.transform.location
    waypoint_lst.append((loc.x,loc.y)) 
    
print(len(waypoint_lst),i)
    # print(asadbhai)
# Out:
# Done
# 123 123

# %%
'''spectator mode'''


transform = carla.Transform()
transform.rotation.yaw = 180
transform.rotation.pitch = 0
transform.rotation.roll = 0

spectator = world.get_spectator() 
transform = carla.Transform(vehicle.get_transform().transform(carla.Location(x=-5,z=20)), carla.Rotation(yaw=90, pitch=-90)) 
spectator.set_transform(transform)

# %% [markdown]
# Changing the ld from kdd*vel to 6.3 makes a difference

# %%
''' Creating a pure persuit controller
The target here would be the rear vehicle
'''


##### Start Your Engines #########
control = carla.VehicleControl()
control.throttle = 0.5
vehicle.apply_control(control)

implemented_route = []
Error_cal = [] # store lateral error and the index
from tqdm import tqdm
print(f"The way point list lenghth is {len(waypoint_lst)}")
for t in range(len(waypoint_lst)):
    print(f't = {t}')
    # throttle, steer = controller.get_control(traj, speed, desired_speed=25, dt=1./FPS)

    ###### Geting Current information #########
    vehicle_transform = vehicle.get_transform()
    loc = vehicle_transform.location
    x_,y_,z_ = (loc.x,loc.y,loc.z)
    vel_array = vehicle.get_velocity() 
    x_dot, y_dot, z_dot = (vel_array.x, vel_array.y, vel_array.z)
    vel = np.hypot(x_dot, y_dot)
    
    implemented_route.append((x_,y_))
    
    print(f"The velocity = {vel}")

    yaw = vehicle_transform.rotation.yaw
    yaw = np.radians(yaw)  ### Converting in radians




    _, target, is_end = get_target_wp_index(loc, waypoint_lst)
    if is_end:
        print("You have reached your destination") 
        control.brake = True
        break
    # target = waypoint_lst[t]
    tx, ty = target
    

    

    ######### Look ahead distance ##########
    # ld_approx = np.clip(Kdd * vel ,3, 30) #### Might change in the future
    # Kdd = 2/(ld_approx)**2 # Need to check if this is correct: sourc: https://www.shuffleai.blog/blog/Three_Methods_of_Vehicle_Lateral_Control.html. See section 2.4
    ld_approx = 6.3


    ######### Calculate Alpha #########3
    alpha = math.atan2((ty - y_), (tx-x_)) - yaw
    print(f"Alpha = {alpha}")

    # ld_approx = (tx-x_)/math.cos(alpha)

    error = 2 * math.sin(alpha)/ld_approx
    Error_cal.append(error)
    print(f"The error is {error}")


    ############### Steering Angle ####################3
    del_ = np.clip(math.atan2(2*L*math.sin(alpha),ld_approx ),-1,1)
    print(f'Steering angle = {del_}')

    control.steer = del_
    vehicle.apply_control(control)


    print('-----------------------')
    
    time.sleep(0.5)
    
control.throttle = 0
vehicle.apply_control(control)
# Out:
# The way point list lenghth is 123
# t = 0
# The velocity = 1.4137071947887433e-07
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (99.00300598144531, 53.221126556396484), and the indexis = 4
# Alpha = 2.2826539458620232e-07
# The error is 7.246520463053979e-08
# Steering angle = 2.0833746331279887e-07
# -----------------------
# t = 1
# The velocity = 4.3672260401467705e-07
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (99.00300598144531, 53.221126556396484), and the indexis = 4
# Alpha = 2.2826539458620232e-07
# The error is 7.246520463053979e-08
# Steering angle = 2.0833746331279887e-07
# -----------------------
# t = 2
# The velocity = 1.7528570686169065e-08
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (99.00300598144531, 53.221126556396484), and the indexis = 4
# Alpha = 2.2826539458620232e-07
# The error is 7.246520463053979e-08
# Steering angle = 2.0833746331279887e-07
# -----------------------
# t = 3
# The velocity = 4.972321701710297e-08
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (99.00300598144531, 53.221126556396484), and the indexis = 4
# Alpha = 2.2826539458620232e-07
# The error is 7.246520463053979e-08
# Steering angle = 2.0833746331279887e-07
# -----------------------
# t = 4
# The velocity = 1.783987487327095e-08
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (99.00300598144531, 53.221126556396484), and the indexis = 4
# Alpha = 2.2826539458620232e-07
# The error is 7.246520463053979e-08
# Steering angle = 2.0833746331279887e-07
# -----------------------
# t = 5
# The velocity = 0.17466402482631246
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (99.00300598144531, 53.221126556396484), and the indexis = 4
# Alpha = 5.168263313093391e-06
# The error is 1.6407185120858358e-06
# Steering angle = 4.717065722211792e-06
# -----------------------
# t = 6
# The velocity = 2.1089342616396567
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (99.00300598144531, 53.221126556396484), and the indexis = 4
# Alpha = -0.00048531661874040566
# The error is -0.0001540687618060706
# Steering angle = -0.00044294766122328534
# -----------------------
# t = 7
# The velocity = 2.6911088674023085
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (98.98255157470703, 56.22105407714844), and the indexis = 5
# Alpha = -0.0003385135333358047
# The error is -0.00010746461170497801
# Steering angle = -0.00030896074882101566
# -----------------------
# t = 8
# The velocity = 3.2020361195441
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (98.98255157470703, 56.22105407714844), and the indexis = 5
# Alpha = -7.794552716866576e-05
# The error is -2.4744611774520432e-05
# Steering angle = -7.114075873173159e-05
# -----------------------
# t = 9
# The velocity = 3.684301486270969
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (98.98255157470703, 56.22105407714844), and the indexis = 5
# Alpha = 0.00023929396708211037
# The error is 7.596633803123314e-05
# Steering angle = 0.00021840321836718652
# -----------------------
# t = 10
# The velocity = 4.141573915962235
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (98.71600341796875, 58.807857513427734), and the indexis = 6
# Alpha = 0.02292735253201683
# The error is 0.007277886954318555
# Steering angle = 0.020920872223235965
# -----------------------
# t = 11
# The velocity = 4.45990863136497
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (98.71600341796875, 58.807857513427734), and the indexis = 6
# Alpha = 0.014814739220879947
# The error is 0.0047029197816865105
# Steering angle = 0.013520070523817587
# -----------------------
# t = 12
# The velocity = 4.859712810326
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (97.82062530517578, 61.188255310058594), and the indexis = 7
# Alpha = 0.0863666758637569
# The error is 0.027383918987773537
# Steering angle = 0.07856670996966186
# -----------------------
# t = 13
# The velocity = 5.0708082243380375
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (97.82062530517578, 61.188255310058594), and the indexis = 7
# Alpha = 0.0402679324544708
# The error is 0.012780016154013656
# Steering angle = 0.03672602549666659
# -----------------------
# t = 14
# The velocity = 5.142020405878492
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (94.40386962890625, 64.88324737548828), and the indexis = 9
# Alpha = 0.2949598561004676
# The error is 0.09228617146676539
# Steering angle = 0.259347271910121
# -----------------------
# t = 15
# The velocity = 5.29649931111069
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (94.40386962890625, 64.88324737548828), and the indexis = 9
# Alpha = 0.17580313239832135
# The error is 0.055523475283714416
# Steering angle = 0.15829446859948587
# -----------------------
# t = 16
# The velocity = 5.615417114912642
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (92.10411071777344, 65.9386978149414), and the indexis = 10
# Alpha = 0.25565019090391283
# The error is 0.08027762576025697
# Steering angle = 0.2268263277462728
# -----------------------
# t = 17
# The velocity = 5.813687526644999
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (89.60855102539062, 66.35713195800781), and the indexis = 11
# Alpha = 0.32588107291059876
# The error is 0.10163289244276527
# Steering angle = 0.2842805519604286
# -----------------------
# t = 18
# The velocity = 5.896802454684569
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (85.98224639892578, 66.35848999023438), and the indexis = 12
# Alpha = 0.43085982546181123
# The error is 0.13258800004195215
# Steering angle = 0.3641868817251535
# -----------------------
# t = 19
# The velocity = 6.000289954835343
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (85.98224639892578, 66.35848999023438), and the indexis = 13
# Alpha = 0.26695901585159376
# The error is 0.08374583996115205
# Steering angle = 0.2362722457341516
# -----------------------
# t = 20
# The velocity = 6.155713261732865
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (82.98224639892578, 66.35465240478516), and the indexis = 14
# Alpha = 0.2503652675606971
# The error is 0.07865328730764894
# Steering angle = 0.22238802050684467
# -----------------------
# t = 21
# The velocity = 6.340211958834512
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (79.98225402832031, 66.35081481933594), and the indexis = 15
# Alpha = 0.15273080163062192
# The error is 0.04829768558384932
# Steering angle = 0.13797360601378503
# -----------------------
# t = 22
# The velocity = 6.509995270644741
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (76.98225402832031, 66.34698486328125), and the indexis = 16
# Alpha = 0.10454423287966508
# The error is 0.03312822252304494
# Steering angle = 0.09495720101719685
# -----------------------
# t = 23
# The velocity = 6.663938869286815
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (76.98225402832031, 66.34698486328125), and the indexis = 16
# Alpha = 0.046130623969981244
# The error is 0.014639449032101777
# Steering angle = 0.04206359005412001
# -----------------------
# t = 24
# The velocity = 6.819020545171306
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (70.98226165771484, 66.33930969238281), and the indexis = 18
# Alpha = 0.057771806101312606
# The error is 0.01833005559083224
# Steering angle = 0.05265020625293409
# -----------------------
# t = 25
# The velocity = 6.963354330148904
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (67.98226165771484, 66.3354721069336), and the indexis = 19
# Alpha = 0.03792503960729343
# The error is 0.01203680918808108
# Steering angle = 0.03459202211163269
# -----------------------
# t = 26
# The velocity = 7.106447971760609
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (67.98226165771484, 66.3354721069336), and the indexis = 19
# Alpha = 0.016366748137901066
# The error is 0.005195561096191798
# Steering angle = 0.014936127362664442
# -----------------------
# t = 27
# The velocity = 7.245380641304316
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (64.98226165771484, 66.3316421508789), and the indexis = 20
# Alpha = 0.01432204898797984
# The error is 0.0045465267832671494
# Steering angle = 0.01307052013502319
# -----------------------
# t = 28
# The velocity = 7.379063997094738
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (61.982269287109375, 66.32780456542969), and the indexis = 21
# Alpha = 0.013616774633680162
# The error is 0.004322652013232462
# Steering angle = 0.012426984798973351
# -----------------------
# t = 29
# The velocity = 7.507912211069924
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (61.982269287109375, 66.32780456542969), and the indexis = 21
# Alpha = 0.008711667308190396
# The error is 0.002765573687608523
# Steering angle = 0.007950856806854712
# -----------------------
# t = 30
# The velocity = 7.632397750833161
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (58.05227279663086, 66.3227767944336), and the indexis = 22
# Alpha = 0.010492953042728015
# The error is 0.0033310350776161526
# Steering angle = 0.009576433092005966
# -----------------------
# t = 31
# The velocity = 7.7521729518762115
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (58.05227279663086, 66.3227767944336), and the indexis = 23
# Alpha = 0.007592160205095677
# The error is 0.0024101864345457196
# Steering angle = 0.006929175099281124
# -----------------------
# t = 32
# The velocity = 7.867767260823261
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (55.052276611328125, 66.31893920898438), and the indexis = 24
# Alpha = 0.007905160663553623
# The error is 0.0025095486760319014
# Steering angle = 0.007214827254756222
# -----------------------
# t = 33
# The velocity = 7.979065695504895
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (52.052276611328125, 66.31510162353516), and the indexis = 25
# Alpha = 0.007404331472866232
# The error is 0.0023505599419216504
# Steering angle = 0.00675775696168773
# -----------------------
# t = 34
# The velocity = 8.086286702517414
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (52.052276611328125, 66.31510162353516), and the indexis = 25
# Alpha = 0.005746336343080749
# The error is 0.0018242237202423413
# Steering angle = 0.00524459510961165
# -----------------------
# t = 35
# The velocity = 8.15560763941553
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (49.05228042602539, 66.31127166748047), and the indexis = 26
# Alpha = 0.005767066797453868
# The error is 0.0018308047078214142
# Steering angle = 0.005263514926607979
# -----------------------
# t = 36
# The velocity = 8.288948130259188
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (43.052284240722656, 66.30359649658203), and the indexis = 28
# Alpha = -6.2781458509013035
# The error is 0.0015998206183717506
# Steering angle = 0.004599451843808596
# -----------------------
# t = 37
# The velocity = 8.352893017091482
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (43.052284240722656, 66.30359649658203), and the indexis = 28
# Alpha = -6.278577666650376
# The error is 0.001462737849393615
# Steering angle = 0.00420534652639844
# -----------------------
# t = 38
# The velocity = 8.475000349728703
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (40.05228805541992, 66.29975891113281), and the indexis = 29
# Alpha = -6.279318049726259
# The error is 0.0012276977186531546
# Steering angle = 0.003529616283510043
# -----------------------
# t = 39
# The velocity = 8.533205068129542
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (37.05228805541992, 66.29592895507812), and the indexis = 30
# Alpha = -6.27954220830217
# The error is 0.0011565367678678965
# Steering angle = 0.003325030953906086
# -----------------------
# t = 40
# The velocity = 8.617065447433708
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (34.05229187011719, 66.2920913696289), and the indexis = 31
# Alpha = -6.279710018346426
# The error is 0.0011032640754351987
# Steering angle = 0.0031718735796571777
# -----------------------
# t = 41
# The velocity = 8.696950101761402
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (31.05229377746582, 66.28825378417969), and the indexis = 32
# Alpha = -6.279870864689194
# The error is 0.0010522020387021957
# Steering angle = 0.003025071633699318
# -----------------------
# t = 42
# The velocity = 8.773040717139763
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (27.14229393005371, 66.28325653076172), and the indexis = 33
# Alpha = -6.28004712006352
# The error is 0.0009962482429028408
# Steering angle = 0.002864205865981715
# -----------------------
# t = 43
# The velocity = 8.845497950555911
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (27.14229393005371, 66.28325653076172), and the indexis = 33
# Alpha = -6.279949662150635
# The error is 0.0010271871057390798
# Steering angle = 0.002953154344031531
# -----------------------
# t = 44
# The velocity = 8.914490639138549
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (27.14229393005371, 66.28325653076172), and the indexis = 34
# Alpha = -6.279823056461423
# The error is 0.0010673791692946382
# Steering angle = 0.0030687054790670535
# -----------------------
# t = 45
# The velocity = 8.980164566692093
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (24.142295837402344, 66.2794189453125), and the indexis = 35
# Alpha = -6.280400973670035
# The error is 0.0008839142577639024
# Steering angle = 0.002541248020646735
# -----------------------
# t = 46
# The velocity = 9.042708761344649
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (21.142297744750977, 66.27558135986328), and the indexis = 36
# Alpha = 0.0024586928681751274
# The error is 0.0007805366320548872
# Steering angle = 0.0022440390503726424
# -----------------------
# t = 47
# The velocity = 9.10225335507547
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (18.142301559448242, 66.2717514038086), and the indexis = 37
# Alpha = 0.002400405094185487
# The error is 0.000762032631434693
# Steering angle = 0.0021908403101832544
# -----------------------
# t = 48
# The velocity = 9.158921960548353
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (12.142306327819824, 66.26407623291016), and the indexis = 39
# Alpha = -6.281037518881854
# The error is 0.0006818370306168924
# Steering angle = 0.001960278952102598
# -----------------------
# t = 49
# The velocity = 9.212875481135145
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (9.142309188842773, 66.26023864746094), and the indexis = 40
# Alpha = -6.280848624533121
# The error is 0.0007418033396988747
# Steering angle = 0.002132681368248962
# -----------------------
# t = 50
# The velocity = 9.28079963178033
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (6.142311096191406, 66.25640869140625), and the indexis = 41
# Alpha = -6.28066724493571
# The error is 0.0007993839945578398
# Steering angle = 0.0022982249380614065
# -----------------------
# t = 51
# The velocity = 9.328935464806404
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (3.142313241958618, 66.25257110595703), and the indexis = 42
# Alpha = -6.280879227402586
# The error is 0.000732088169220297
# Steering angle = 0.002104750378506253
# -----------------------
# t = 52
# The velocity = 9.375021859050113
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (0.14231696724891663, 66.24873352050781), and the indexis = 43
# Alpha = 0.002119082587654031
# The error is 0.0006727241275218319
# Steering angle = 0.0019340794550416216
# -----------------------
# t = 53
# The velocity = 9.428262730511136
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-2.8576810359954834, 66.2448959350586), and the indexis = 44
# Alpha = 0.0020159521169023087
# The error is 0.0006399843655269437
# Steering angle = 0.0018399529745450232
# -----------------------
# t = 54
# The velocity = 9.42813852494358
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-5.85767936706543, 66.2410659790039), and the indexis = 45
# Alpha = 0.00028618134215419033
# The error is 9.085121849137347e-05
# Steering angle = 0.00026119724722272473
# -----------------------
# t = 55
# The velocity = 9.462264329888118
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-8.857675552368164, 66.23722839355469), and the indexis = 46
# Alpha = -0.0006735353031421809
# The error is -0.00021382071498962614
# Steering angle = -0.000614734478159422
# -----------------------
# t = 56
# The velocity = 9.489037974964042
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-11.857675552368164, 66.23339080810547), and the indexis = 47
# Alpha = -0.0004589308940672332
# The error is -0.0001456923422087033
# Steering angle = -0.0004188654593536131
# -----------------------
# t = 57
# The velocity = 9.51479390200759
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-14.857671737670898, 66.22955322265625), and the indexis = 48
# Alpha = -0.0001248607370563093
# The error is -3.963832912123023e-05
# Steering angle = -0.00011396019573020604
# -----------------------
# t = 58
# The velocity = 9.547365870831298
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-17.857667922973633, 66.22571563720703), and the indexis = 49
# Alpha = 1.0015544404051724e-05
# The error is 3.179537905995009e-06
# Steering angle = 9.141171479481037e-06
# -----------------------
# t = 59
# The velocity = 9.577989686413288
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-20.857667922973633, 66.22188568115234), and the indexis = 50
# Alpha = -4.3685498378298604e-05
# The error is -1.3868412179175726e-05
# Steering angle = -3.987168499400152e-05
# -----------------------
# t = 60
# The velocity = 9.606772663798695
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-27.017662048339844, 66.21400451660156), and the indexis = 52
# Alpha = -4.5527663258493334e-05
# The error is -1.4453226426274694e-05
# Steering angle = -4.1553025951623846e-05
# -----------------------
# t = 61
# The velocity = 9.627221738315235
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-27.017662048339844, 66.21400451660156), and the indexis = 52
# Alpha = -5.331123600216259e-05
# The error is -1.6924201897431762e-05
# Steering angle = -4.865708041671758e-05
# -----------------------
# t = 62
# The velocity = 9.653049237072507
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-29.7674560546875, 66.04661560058594), and the indexis = 54
# Alpha = 0.01710590087990793
# The error is 0.005430179892246746
# Steering angle = 0.015610499037830192
# -----------------------
# t = 63
# The velocity = 9.676260714472274
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-32.42102813720703, 65.45503234863281), and the indexis = 55
# Alpha = 0.06639103155134363
# The error is 0.021061037960822
# Steering angle = 0.060476646518190125
# -----------------------
# t = 64
# The velocity = 9.680371106061001
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-34.947357177734375, 64.45052337646484), and the indexis = 56
# Alpha = 0.12217961505781849
# The error is 0.03869074979942705
# Steering angle = 0.11078049216216919
# -----------------------
# t = 65
# The velocity = 9.657282847803016
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-39.21615982055664, 61.34925079345703), and the indexis = 58
# Alpha = 0.23958668910096748
# The error is 0.07533369573461333
# Steering angle = 0.21329003928859527
# -----------------------
# t = 66
# The velocity = 9.519834646070045
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-41.45238494873047, 56.83279800415039), and the indexis = 60
# Alpha = 0.33124049981705195
# The error is 0.10324328384851703
# Steering angle = 0.2885408973986015
# -----------------------
# t = 67
# The velocity = 9.299996138978308
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-41.66096878051758, 51.705543518066406), and the indexis = 61
# Alpha = 0.34663672813501356
# The error is 0.10785285975766727
# Steering angle = 0.30067589185389626
# -----------------------
# t = 68
# The velocity = 9.117428432753421
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-41.669410705566406, 48.7055549621582), and the indexis = 63
# Alpha = 0.13595588053887409
# The error is 0.04302775640427273
# Steering angle = 0.12307951773681337
# -----------------------
# t = 69
# The velocity = 9.170674888000695
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-41.677852630615234, 45.70556640625), and the indexis = 64
# Alpha = 0.02442291982210798
# The error is 0.0077525371221168595
# Steering angle = 0.022284854497394275
# -----------------------
# t = 70
# The velocity = 9.22359843608253
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-41.686771392822266, 42.535579681396484), and the indexis = 65
# Alpha = 0.033347841835398295
# The error is 0.010584654373262798
# Steering angle = 0.030421493149247362
# -----------------------
# t = 71
# The velocity = 9.27032289661373
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-41.64381408691406, 39.68611145019531), and the indexis = 67
# Alpha = 0.04730337084630687
# The error is 0.015011343411431899
# Steering angle = 0.04313084738459795
# -----------------------
# t = 72
# The velocity = 9.301172012842084
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-41.17356491088867, 37.06462860107422), and the indexis = 68
# Alpha = 0.09701826292860538
# The error is 0.030751154425499753
# Steering angle = 0.08818029941375248
# -----------------------
# t = 73
# The velocity = 9.322293437225731
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-40.216453552246094, 34.579219818115234), and the indexis = 69
# Alpha = 0.16435263378334342
# The error is 0.05194086434878167
# Steering angle = 0.14823461189893503
# -----------------------
# t = 74
# The velocity = 9.299388453200502
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-34.8490104675293, 29.088247299194336), and the indexis = 72
# Alpha = 0.44801062571077555
# The error is 0.13751534865614645
# Steering angle = 0.37649707158362616
# -----------------------
# t = 75
# The velocity = 8.902970986591422
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-28.72602081298828, 28.104219436645508), and the indexis = 74
# Alpha = 0.49909389550681615
# The error is 0.15194608266676113
# Steering angle = 0.41186052853921473
# -----------------------
# t = 76
# The velocity = 8.659047581108664
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-28.72602081298828, 28.104219436645508), and the indexis = 75
# Alpha = 0.21574137093357676
# The error is 0.06795926079515092
# Steering angle = 0.19295210020713238
# -----------------------
# t = 77
# The velocity = 8.730746322167475
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-25.726032257080078, 28.1125545501709), and the indexis = 76
# Alpha = 0.1371206379237035
# The error is 0.04339407928275408
# Steering angle = 0.12411668880703822
# -----------------------
# t = 78
# The velocity = 8.777880629717693
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-22.726043701171875, 28.12088966369629), and the indexis = 77
# Alpha = 0.10347273235677598
# The error is 0.03278990186446528
# Steering angle = 0.09399318504503817
# -----------------------
# t = 79
# The velocity = 8.835150610489803
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-19.726055145263672, 28.129226684570312), and the indexis = 78
# Alpha = 0.03372496156708532
# The error is 0.010704307604338489
# Steering angle = 0.0307651743152783
# -----------------------
# t = 80
# The velocity = 8.87356674776797
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-13.726078987121582, 28.145896911621094), and the indexis = 80
# Alpha = 0.05536579212774053
# The error is 0.017567463602467265
# Steering angle = 0.05046357778811519
# -----------------------
# t = 81
# The velocity = 8.9363954268641
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-10.726089477539062, 28.154232025146484), and the indexis = 81
# Alpha = 0.021055771252944985
# The error is 0.006683877922915369
# Steering angle = 0.01921378429809389
# -----------------------
# t = 82
# The velocity = 8.98672603037753
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-7.726100921630859, 28.162569046020508), and the indexis = 82
# Alpha = 0.0072602105414452875
# The error is 0.0023048084951963993
# Steering angle = 0.00662622744297297
# -----------------------
# t = 83
# The velocity = 9.034686874802908
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-4.726114273071289, 28.1709041595459), and the indexis = 83
# Alpha = 0.005770244760984266
# The error is 0.001831813568346296
# Steering angle = 0.005266415320217028
# -----------------------
# t = 84
# The velocity = 9.09548001216753
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (-1.7261254787445068, 28.17923927307129), and the indexis = 84
# Alpha = 0.004686299460710315
# The error is 0.0014877086691357448
# Steering angle = 0.004277136341746289
# -----------------------
# t = 85
# The velocity = 9.138766739957617
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (1.2738630771636963, 28.18757438659668), and the indexis = 85
# Alpha = 0.004897680161790655
# The error is 0.0015548128830107772
# Steering angle = 0.004470057265732787
# -----------------------
# t = 86
# The velocity = 9.193529281654275
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (4.273853302001953, 28.195911407470703), and the indexis = 86
# Alpha = 0.0027579890324199025
# The error is 0.0008755509638028654
# Steering angle = 0.0025172037043216617
# -----------------------
# t = 87
# The velocity = 9.232493378416715
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (7.273841857910156, 28.204246520996094), and the indexis = 87
# Alpha = 0.0025122776778106195
# The error is 0.0007975476301867647
# Steering angle = 0.0022929454183162204
# -----------------------
# t = 88
# The velocity = 9.269744154077221
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (10.27383041381836, 28.212581634521484), and the indexis = 88
# Alpha = 0.002188684169561144
# The error is 0.0006948198165519346
# Steering angle = 0.001997604315487168
# -----------------------
# t = 89
# The velocity = 9.316851301932559
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (13.273818969726562, 28.220916748046875), and the indexis = 89
# Alpha = 0.0010168120139027723
# The error is 0.0003227974091072997
# Steering angle = 0.0009280422847540608
# -----------------------
# t = 90
# The velocity = 9.350346160466398
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (16.2738037109375, 28.229251861572266), and the indexis = 90
# Alpha = 0.0009629855692009101
# The error is 0.00030570965725869325
# Steering angle = 0.0008789150383004987
# -----------------------
# t = 91
# The velocity = 9.382353948582413
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (19.273792266845703, 28.23758888244629), and the indexis = 91
# Alpha = 0.0009060042062516952
# The error is 0.0002876203435884882
# Steering angle = 0.0008269082993431343
# -----------------------
# t = 92
# The velocity = 9.422808735085185
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (22.273780822753906, 28.24592399597168), and the indexis = 92
# Alpha = 0.00042574371450794686
# The error is 0.00013515673068139423
# Steering angle = 0.000388575581151871
# -----------------------
# t = 93
# The velocity = 9.451564483338084
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (26.40376853942871, 28.25739860534668), and the indexis = 93
# Alpha = 0.0005214791830212767
# The error is 0.00016554893948763665
# Steering angle = 0.00047595316508750404
# -----------------------
# t = 94
# The velocity = 9.479031580697999
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (26.403766632080078, 28.25739860534668), and the indexis = 94
# Alpha = 6.388479087266635e-05
# The error is 2.0280885977527365e-05
# Steering angle = 5.830754711931375e-05
# -----------------------
# t = 95
# The velocity = 9.505256815185925
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (29.264568328857422, 28.304237365722656), and the indexis = 95
# Alpha = 0.0040033765455029695
# The error is 0.0012709097942253016
# Steering angle = 0.0036538493979315326
# -----------------------
# t = 96
# The velocity = 9.530295283370364
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (31.845666885375977, 28.792335510253906), and the indexis = 96
# Alpha = 0.0487323929544784
# The error is 0.01546447828221663
# Steering angle = 0.04443111444675394
# -----------------------
# t = 97
# The velocity = 9.546649507224544
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (36.42421340942383, 31.308998107910156), and the indexis = 98
# Alpha = 0.2065973550912218
# The error is 0.0651208912961266
# Steering angle = 0.18507992141574398
# -----------------------
# t = 98
# The velocity = 9.458312039825229
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (34.26784896850586, 29.808876037597656), and the indexis = 97
# Alpha = -0.026387041399156624
# The error is -0.008375866474716038
# Steering angle = -0.02407596314255796
# -----------------------
# t = 99
# The velocity = 9.471668638702804
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (38.18721008300781, 33.21669006347656), and the indexis = 99
# Alpha = 0.2490888700686465
# The error is 0.07826065129404335
# Steering angle = 0.22131384505597954
# -----------------------
# t = 100
# The velocity = 9.325591966631999
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (40.19703674316406, 37.95734405517578), and the indexis = 101
# Alpha = 0.4735675544958196
# The error is 0.14478225874516776
# Steering angle = 0.3944351800729091
# -----------------------
# t = 101
# The velocity = 8.98252860808692
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (40.38964080810547, 41.945499420166016), and the indexis = 102
# Alpha = 0.45120640435674153
# The error is 0.13842905416766507
# Steering angle = 0.37876683372588105
# -----------------------
# t = 102
# The velocity = 8.801804889779628
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (40.38964080810547, 41.945499420166016), and the indexis = 103
# Alpha = 0.17431544653529152
# The error is 0.05505841234525116
# Steering angle = 0.1569903658683344
# -----------------------
# t = 103
# The velocity = 8.873467743150298
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (40.4289665222168, 44.94524383544922), and the indexis = 104
# Alpha = 0.11698422235898209
# The error is 0.037053199160587184
# Steering angle = 0.10612770236443879
# -----------------------
# t = 104
# The velocity = 8.914572116384706
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (40.468292236328125, 47.944984436035156), and the indexis = 105
# Alpha = 0.09981721717283776
# The error is 0.031635411208183424
# Steering angle = 0.09070225321825981
# -----------------------
# t = 105
# The velocity = 8.953557352175041
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (40.52924728393555, 52.59458541870117), and the indexis = 106
# Alpha = 0.08741133964955039
# The error is 0.027714307168698857
# Steering angle = 0.07951065434412369
# -----------------------
# t = 106
# The velocity = 8.993448907456925
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (40.568572998046875, 55.59432601928711), and the indexis = 108
# Alpha = 0.04039865440778834
# The error is 0.012821481436573664
# Steering angle = 0.036845076940795016
# -----------------------
# t = 107
# The velocity = 9.041163481785842
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (40.723724365234375, 58.81040954589844), and the indexis = 109
# Alpha = 0.005965525064996147
# The error is 0.0018938062482695879
# Steering angle = 0.005444639162669141
# -----------------------
# t = 108
# The velocity = 9.086495590224738
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (40.723724365234375, 58.81040954589844), and the indexis = 109
# Alpha = -0.005859007877754063
# The error is -0.0018599918592065363
# Steering angle = -0.005347425624827062
# -----------------------
# t = 109
# The velocity = 9.129813613176191
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (41.61297607421875, 62.113494873046875), and the indexis = 110
# Alpha = -0.06969695212984339
# The error is -0.022108107436334797
# Steering angle = -0.06347542103985918
# -----------------------
# t = 110
# The velocity = 9.155304354598998
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (45.73234176635742, 67.61127471923828), and the indexis = 112
# Alpha = -0.27191151623294463
# The error is -0.08526133713526264
# Steering angle = -0.24038645919064075
# -----------------------
# t = 111
# The velocity = 9.02432423183972
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (48.87596893310547, 69.24942779541016), and the indexis = 113
# Alpha = -0.2894161662685394
# The error is -0.09060086390604162
# Steering angle = -0.2548152561744225
# -----------------------
# t = 112
# The velocity = 8.952291264440097
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (48.87596893310547, 69.24942779541016), and the indexis = 113
# Alpha = -0.08846856470887798
# The error is -0.028048637217391266
# Steering angle = -0.08046571640871551
# -----------------------
# t = 113
# The velocity = 9.017442441207711
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (52.37373352050781, 69.8155288696289), and the indexis = 114
# Alpha = -0.20151458897125574
# The error is -0.0635407937732567
# Steering angle = -0.18068740221578683
# -----------------------
# t = 114
# The velocity = 8.982698985041015
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (34.05229187011719, 66.2920913696289), and the indexis = 31
# Alpha = 2.2430282025993407
# The error is 0.2483916670537829
# Steering angle = 0.6201437495682619
# -----------------------
# t = 115
# The velocity = 8.290996958748941
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (37.05228805541992, 66.29592895507812), and the indexis = 30
# Alpha = -4.032521979393359
# The error is 0.24687502880076026
# Steering angle = 0.6172501054936329
# -----------------------
# t = 116
# The velocity = 7.792712641969589
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (61.047794342041016, 69.82661437988281), and the indexis = 117
# Alpha = -1.3133864336170182
# The error is -0.3070008259985471
# Steering angle = -0.7231336345381315
# -----------------------
# t = 117
# The velocity = 7.127881685657157
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (61.047794342041016, 69.82661437988281), and the indexis = 117
# Alpha = -1.5311175531438674
# The error is -0.3172104446783052
# Steering angle = -0.7393946129028746
# -----------------------
# t = 118
# The velocity = 0.192303414130135
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (61.047794342041016, 69.82661437988281), and the indexis = 117
# Alpha = -1.506234786855808
# The error is -0.31679892939342325
# Steering angle = -0.738748328737164
# -----------------------
# t = 119
# The velocity = 0.04177345571986916
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (61.047794342041016, 69.82661437988281), and the indexis = 117
# Alpha = -1.508293075448711
# The error is -0.3168404151168124
# Steering angle = -0.7388135165187186
# -----------------------
# t = 120
# The velocity = 0.029074418823129024
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (61.047794342041016, 69.82661437988281), and the indexis = 117
# Alpha = -1.508852423824118
# The error is -0.3168514570855102
# Steering angle = -0.7388308657962763
# -----------------------
# t = 121
# The velocity = 0.02667947507212242
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (61.047794342041016, 69.82661437988281), and the indexis = 117
# Alpha = -1.5093530093962717
# The error is -0.3168612549724825
# Steering angle = -0.738846259898092
# -----------------------
# t = 122
# The velocity = 0.02607584102682928
# the last location in the list (76.04778289794922, 69.84579467773438)
# This line is printed
# The current waypoint is (61.047794342041016, 69.82661437988281), and the indexis = 117
# Alpha = -1.5089077423533646
# The error is -0.3168525437291688
# Steering angle = -0.7388325731145718
# -----------------------

# %%
# vehicle.destroy()
''' Destroy everything'''
try:
    car_lst = world.get_actors().filter('vehicle.*')
    print(car_lst)
    if car_lst:
        for car in car_lst:
            car.destroy()
except:
    print("Nope doesnt work")

for act in actor_lst:
    try: 
        print(act)
        act.destroy()
        print("Those this way")
    except:
        pass
# Out:
# [Actor(id=34, type=vehicle.tesla.model3)]
# Actor(id=34, type=vehicle.tesla.model3)
# Those this way
# Actor(id=35, type=sensor.camera.rgb)
# Those this way

# %%
x_way = []
y_way = []
x_real = []
y_real = []
for x, y in waypoint_lst:
    x_way.append(x)
    y_way.append(y)

for x, y in implemented_route:
    x_real.append(x)
    y_real.append(y)
plt.plot(x_way[0], y_way[0], label = "starting point", marker = 'o',markersize = 15)
plt.plot(x_way[-1], y_way[-1], label = "Ending Point", marker = 'o',markersize = 15)
plt.plot(x_way, y_way, label = "waypoint", linewidth = 1)
plt.plot(x_real, y_real, label = 'Path')

# naming the x axis
plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')
# giving a title to my graph
plt.title('Path and Waypoints on the same graph')
  
# show a legend on the plot
plt.legend()
  
# function to show the plot
plt.show()

# %%
# error_plot = plt.figure()
# print(error_plot)
# error_plot.
from mpl_toolkits import mplot3d
plt.plot(Error_cal, label = "error")
print(len(Error_cal), len(x_real),len(y_real), len(x_way))

fig = plt.figure()
 
# syntax for 3-D projection
ax = plt.axes(projection ='3d')
 
# defining all 3 axis
z = np.linspace(0, 1, 100)
x = z * np.sin(25 * z)
y = z * np.cos(25 * z)
 
# plotting
ax.plot3D(x_real, y_real, Error_cal, 'green')
ax.plot3D(x_way[0], y_way[0],Error_cal[0], label = "starting point", marker = 'o',markersize = 15)
ax.plot3D(x_way[-1], y_way[-1], Error_cal[-1], label = "Ending Point", marker = 'o',markersize = 15)
ax.set_title('3D line plot geeks for geeks')
ax.view_init(50, 35)
plt.legend()
plt.show()
# Out:
# 123 123 123 123

# %%
settings.no_rendering_mode = False
world.apply_settings(settings)
# Out:
# 6135
