# %% [markdown]
# # PRM In CARLA

# %%
import sys
import os
import glob
import math 
import random 
import time 
import numpy as np
import cv2
import open3d as o3d
from matplotlib import cm
import carla

#  Trying to import the Global and Local 
sys.path.append(("C:/CARLA/WindowsNoEditor/PythonAPI/carla"))
from agents.navigation.global_route_planner import GlobalRoutePlanner

# To import a basic agent
from agents.navigation.basic_agent import BasicAgent

# To import a behavior agent
from agents.navigation.behavior_agent import BehaviorAgent


''' Connecting to Carla and fetching blue-print of the map'''

# Connect the client and set up bp library and spawn point
client = carla.Client('localhost', 2000)
client.set_timeout(20.0)
world = client.get_world()
bp_lib = world.get_blueprint_library() 
spawn_points = world.get_map().get_spawn_points()
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
map =  world.get_map()
waypoints = map.generate_waypoints(1) #
print(waypoints)
for waypoint in waypoints:
    world.debug.draw_string(waypoint.transform.location, '^', draw_shadow=False,
        color=carla.Color(r=0, g=0, b=255), life_time=10.0,
        persistent_lines=True)
# Out:
# [<carla.libcarla.Waypoint object at 0x0000020265007030>, <carla.libcarla.Waypoint object at 0x00000202650F9150>, <carla.libcarla.Waypoint object at 0x00000202650F93F0>, <carla.libcarla.Waypoint object at 0x00000202650F92D0>, <carla.libcarla.Waypoint object at 0x00000202650F9450>, <carla.libcarla.Waypoint object at 0x00000202650F94B0>, <carla.libcarla.Waypoint object at 0x00000202650F9510>, <carla.libcarla.Waypoint object at 0x00000202650F9570>, <carla.libcarla.Waypoint object at 0x00000202650F95D0>, <carla.libcarla.Waypoint object at 0x00000202650F9630>, <carla.libcarla.Waypoint object at 0x00000202650F9690>, <carla.libcarla.Waypoint object at 0x00000202650F96F0>, <carla.libcarla.Waypoint object at 0x000002026510EC30>, <carla.libcarla.Waypoint object at 0x000002026510EC90>, <carla.libcarla.Waypoint object at 0x000002026510ECF0>, <carla.libcarla.Waypoint object at 0x000002026510ED50>, <carla.libcarla.Waypoint object at 0x000002026510EDB0>, <carla.libcarla.Waypoint object at 0x000002026510EE10>, <carla.libcarla.Waypoint object at 0x000002026510EE70>, <carla.libcarla.Waypoint object at 0x000002026510EED0>, <carla.libcarla.Waypoint object at 0x000002026510EF30>, <carla.libcarla.Waypoint object at 0x000002026510EF90>, <carla.libcarla.Waypoint object at 0x000002026510F030>, <carla.libcarla.Waypoint object at 0x000002026510F090>, <carla.libcarla.Waypoint object at 0x000002026510F0F0>, <carla.libcarla.Waypoint object at 0x000002026510F150>, <carla.libcarla.Waypoint object at 0x000002026510F1B0>, <carla.libcarla.Waypoint object at 0x000002026510F210>, <carla.libcarla.Waypoint object at 0x000002026510F270>, <carla.libcarla.Waypoint object at 0x000002026510F2D0>, <carla.libcarla.Waypoint object at 0x000002026510F330>, <carla.libcarla.Waypoint object at 0x000002026510F390>, <carla.libcarla.Waypoint object at 0x000002026510F3F0>, <carla.libcarla.Waypoint object at 0x000002026510F450>, <carla.libcarla.Waypoint object at 0x000002026510F4B0>, <carla.libcarla.Waypoint object at 0x000002026510F510>, <carla.libcarla.Waypoint object at 0x000002026510F570>, <carla.libcarla.Waypoint object at 0x000002026510F5D0>, <carla.libcarla.Waypoint object at 0x000002026510F630>, <carla.libcarla.Waypoint object at 0x000002026510F690>, <carla.libcarla.Waypoint object at 0x000002026510F6F0>, <carla.libcarla.Waypoint object at 0x000002026510F750>, <carla.libcarla.Waypoint object at 0x000002026510F7B0>, <carla.libcarla.Waypoint object at 0x000002026510F810>, <carla.libcarla.Waypoint object at 0x000002026510F870>, <carla.libcarla.Waypoint object at 0x000002026510F8D0>, <carla.libcarla.Waypoint object at 0x000002026510F930>, <carla.libcarla.Waypoint object at 0x000002026510F990>, <carla.libcarla.Waypoint object at 0x000002026510F9F0>, <carla.libcarla.Waypoint object at 0x000002026510FA50>, <carla.libcarla.Waypoint object at 0x000002026510FAB0>, <carla.libcarla.Waypoint object at 0x000002026510FB10>, <carla.libcarla.Waypoint object at 0x000002026510FB70>, <carla.libcarla.Waypoint object at 0x000002026510FBD0>, <carla.libcarla.Waypoint object at 0x000002026510FC30>, <carla.libcarla.Waypoint object at 0x000002026510FC90>, <carla.libcarla.Waypoint object at 0x000002026510FCF0>, <carla.libcarla.Waypoint object at 0x000002026510FD50>, <carla.libcarla.Waypoint object at 0x000002026510FDB0>, <carla.libcarla.Waypoint object at 0x0000020265114030>, <carla.libcarla.Waypoint object at 0x0000020265114090>, <carla.libcarla.Waypoint object at 0x00000202651140F0>, <carla.libcarla.Waypoint object at 0x0000020265114150>, <carla.libcarla.Waypoint object at 0x00000202651141B0>, <carla.libcarla.Waypoint object at 0x0000020265111870>, <carla.libcarla.Waypoint object at 0x00000202651118D0>, <carla.libcarla.Waypoint object at 0x0000020265111930>, <carla.libcarla.Waypoint object at 0x0000020265111990>, <carla.libcarla.Waypoint object at 0x00000202651119F0>, <carla.libcarla.Waypoint object at 0x0000020265111A50>, <carla.libcarla.Waypoint object at 0x0000020265111AB0>, <carla.libcarla.Waypoin ...

# %%
'''Trying to implement RRT'''
